# %%
import pandas as pd

# %%
import os

# %%
# read all csv in one folder
#add a colomn to add month info
for info in os.listdir(r'E:\PY\tweetsAaylisis\tweetsData'):
    domain = os.path.abspath(r'E:\PY\tweetsAaylisis\tweetsData') #获取文件夹的路径
    info_full = os.path.join(domain,info) #将路径与文件名结合起来就是每个文件的完整路径  
    df = pd.read_csv(info_full,encoding='utf-8-sig',low_memory=False)
    #删空列
    #df = df.dropna(axis=1)
    df.dropna(axis=1,how='all') 
    df['Month'] =info[-11:-4]
    #save
    #print(df)
    df.to_csv(info,encoding='utf-8-sig')
    print(info)

# %%
#Description:
Folder_Path = r'E:\PY\tweetsAaylisis\tweetsData2'         
SaveFile_Path =  r'E:\PY\tweetsAaylisis'       #拼接后要保存的文件路径
SaveFile_Name = r'geo_US_-retweet_2019-03_2021-02.csv'            
 
#修改当前工作目录
os.chdir(Folder_Path)
#将该文件夹下的所有文件名存入一个列表
file_list = os.listdir()
 
#读取第一个CSV文件并包含表头
df = pd.read_csv(Folder_Path +'\\'+ file_list[0],encoding='utf-8-sig',low_memory=False) 
 
#将读取的第一个CSV文件写入合并后的文件保存
df.to_csv(SaveFile_Path+'\\'+ SaveFile_Name,encoding="utf_8_sig",index=False)
 
#循环遍历列表中各个CSV文件名，并追加到合并后的文件
for i in range(1,len(file_list)):
    df = pd.read_csv(Folder_Path + '\\'+ file_list[i],low_memory=False)
    df.to_csv(SaveFile_Path+'\\'+ SaveFile_Name,encoding="utf_8_sig",index=False, header=True, mode='a+')

# %%
#删空行
#df1 = pd.read_csv('geo_US_-retweet_2019-03-01_2019-03-31.csv',encoding='utf-8-sig')
df4 = pd.read_csv('geo_US_-retweet_2021-02-01_2021-02-28.csv',skip_blank_lines=True,low_memory=False)

# %%
#delete column==NA row
df[df['geo.place_id'].notna()]
new=df[df['geo.place_id'].notna()]
df.to_csv("original_results_2020-03-01_2020-03-10_geo1.csv",encoding='utf-8-sig')

# %%
df= pd.read_csv("original_results_2020-03-01_2020-03-09_geo.csv")

# %%
df4.to_csv("geo_US_-retweet_2021-02.csv",encoding='utf-8-sig')

# %%
print(list(df))

# %%
df=df[df['geo.place_id'].notna()]

# %%
df

# %%
import csv
pd.read_csv("original_results_2020-03-01_2020-03-10_geo2.csv",usecols=['index','geo.geo.bbox']) \
  .to_csv("new_file.csv", quoting=csv.QUOTE_NONE,sep='|', index=False)

# %%
#csv add local_time column
import pandas as pd
df= pd.read_csv("clean_local_time_2019-03_2020-02_bbox_county_level.csv")

# %%
df[df['local_time'].isin(["n"])]
# Out:
#        Unnamed: 0  Unnamed: 0.1            id    Month  author.username  \
# 66            106           106  1.110000e+18  2019-03          IAmKale
# 18742       30782         30782  1.130000e+18  2019-05      dmvsno1slim
# 26697       43718         43718  1.140000e+18  2019-06            FJZB2
# 33810       55303         55303  1.160000e+18  2019-07          KlausQM
# 34561       56548         56548  1.150000e+18  2019-07   donkeyboy_jack
# 40577       66417         66417  1.150000e+18  2019-07       BeyondEand
# 56662       92542         92542  1.180000e+18  2019-09   RobertZawodski
# 64324      104946        104946  1.180000e+18  2019-10   RobertZawodski
# 65870      107386        107386  1.200000e+18  2019-11    karliburghoff
# 68957      112296        112296  1.200000e+18  2019-11          zulu_61
# 71312      116149        116149  1.190000e+18  2019-11    ZackSanfordMD
# 71509      116473        116473  1.190000e+18  2019-11      Evgeniya_NP
# ...

# %%
df=df[~df['local_time'].isin(["n"])]

# %%
df.to_csv("clean_local_time_2019-03_2020-02_bbox_county_level.csv",encoding="utf_8_sig",index=False)

# %% [markdown]
# ## join 2 tables

# %%
df1 = pd.read_csv('Obesity.csv')

# %%
df2 = pd.read_csv(r'E:\Project\Data\tweet_data\4.2 Sentiment8States54 2Period\sentimentscores_states_2019.csv')

# %%
merge_df = pd.merge(df1, df2, on='state',how='inner')

# %%
merge_df.to_csv("clean_local_time_2019-03_2020-02_bbox_county_level.csv",encoding="utf_8_sig",index=False)
